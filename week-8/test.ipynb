# %%
# !curl ifconfig.me
# !nvidia-smi
# !pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:77077db6-4abc-4b84-a23f-2f7c2b8d1f71

# %%
# %%cuda
# # include <stdio.h>
# # include <cuda_runtime.h>
#
# __global__ void helloFromGPU() {
#     printf("Hello World from GPU thread %d!\n", threadIdx.x);
# }
#
# int main() {
#     // Launch 5 threads on the GPU
#     helloFromGPU<<<1, 5>>>();
#     cudaDeviceSynchronize();
#     return 0;
# }
